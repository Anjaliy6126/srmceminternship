# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjaliy6126/srmceminternship/blob/main/DAY_2_%2C_2_outliers_z_score_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align='center' style='color:blue'>Exercise: Outlier removal using standard deviation and z score<h2>

# %% [markdown]
# You are given bhp.csv which contains property prices in the city of banglore, India. You need to examine price_per_sqft column and do following,
#
# (1) Remove outliers using percentile technique first. Use [0.001, 0.999] for lower and upper bound percentiles
#
# (2) After removing outliers in step 1, you get a new dataframe.
#
# (3) On step(2) dataframe, use 4 standard deviation to remove outliers
#
# (4) Plot histogram for new dataframe that is generated after step (3). Also plot bell curve on same histogram
#
# (5) On step(2) dataframe, use zscore of 4 to remove outliers. This is quite similar to step (3) and you will get exact same result

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv("/content/bhp (1).csv")
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %% [markdown]
# We will quickly examine price_per_sqft column to check min,max,mean and percentile values

# %%
df.price_per_sqft.describe()
# Out:
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# Above, you can see max is 12000000, which is too much price for price per sqft. Looks like this dataset has some very bad outliers so we will first remove those with percentile and then use z score

# %% [markdown]
# Also **plot histogram** to see how is the data distribution

# %%
df.price_per_sqft.hist(bins=20, rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Above chart confirms our understanding that this dataset has some bad outliers. Because we see only one bar with more than 12000 data points but on the right hand side there are data points that have higher value for price per sqft but count of these data points is very tiny compared to 12000 hence we can hardly see any bar

# %% [markdown]
# Using **log scale** can make visualization little better

# %%
plt.figure(figsize=(10,6))
plt.hist(df['price_per_sqft'], bins=20, rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
plt.yscale('log')      # Use logarithmic scale on y-axis
plt.title("Price Per Sqft Distribution (Log Scale)")
plt.show()

# %% [markdown]
# You see atleast few bars on right hand side of our highest building at least :)

# %% [markdown]
# <h3 style='color:purple'>(1) Treat outliers using percentile first</h3>

# %%
upper_limit = df.price_per_sqft.quantile(0.999)
upper_limit
# Out:
# np.float64(50959.36200000098)

# %%
df1 = df[df.price_per_sqft < upper_limit]
df1.shape
# Out:
# (13186, 7)

# %% [markdown]
# Above shows properties that has price_per_sqft value such as 500 rs which is very very low for the city of banglore. You would be very lucky if you can find such as property :)
# Also we have properties that has price per sqft value such as 12000000 which is way too high. It seems almost impossible and even if it is legitimate it can help data analysis process if we remove such a data point

# %%
min_thres, max_thres = df.price_per_sqft.quantile([0.001, 0.999])
min_thres, max_thres
# Out:
# (1366.184, 50959.36200000098)

# %%
df.shape
# Out:
# (13200, 7)

# %%
df2 = df[(df.price_per_sqft >= min_thres) & (df.price_per_sqft <= max_thres)]
df.shape[0] - df2.shape[0]
# Out:
# 28

# %% [markdown]
# **We removed total 28 outliers**

# %% [markdown]
# <h3 style='color:purple'>(2) Now remove outliers using 4 standard deviation</h3>

# %%
import numpy as np

df2.price_per_sqft.describe()
# Out:
# count    13172.000000
# mean      6663.653735
# std       4141.020700
# min       1379.000000
# 25%       4271.000000
# 50%       5438.000000
# 75%       7311.000000
# max      50349.000000
# Name: price_per_sqft, dtype: float64

# %%
mean = np.mean(df2.price_per_sqft)
std = np.std(df2.price_per_sqft)

mean, std
# Out:
# (np.float64(6663.6537351958705), 4140.863506912447)

# %%
lower_limit = mean - 4*std
upper_limit = mean + 4*std

lower_limit, upper_limit
# Out:
# (np.float64(-9899.800292453916), np.float64(23227.107762845655))

# %%
df3 = df2[(df2.price_per_sqft > lower_limit) & (df2.price_per_sqft < upper_limit)]
df3.shape
# Out:
# (13047, 7)

# %%
df2.shape[0] - df3.shape[0]
# Out:
# 125

# %%
df2[(df2.price_per_sqft < lower_limit) | (df2.price_per_sqft > upper_limit)]
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# 760              other  9 Bedroom       600.0   9.0   190.0    9
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft
# 9               36274
# 45              33333
# 190             27083
# 733             23719
# 760             31666
# ...               ...
# 13081           35000
# 13094           27083
# 13127           27083
# 13185           44000
# 13186           27083
#
# [125 rows x 7 columns]

# %% [markdown]
# In this step we removed total 125 outliers

# %%
from scipy.stats import zscore

# %%
df2['zscore'] = zscore(df2.price_per_sqft)
df2.head()
# Out:
# /tmp/ipykernel_730/1248591032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['zscore'] = zscore(df2.price_per_sqft)
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft    zscore
# 0            3699 -0.715951
# 1            4615 -0.494741
# 2            4305 -0.569604
# 3            6245 -0.101103
# 4            4250 -0.582887

# %% [markdown]
# <h3 style='color:purple'>(3) Now remove outliers using z score. Use z score of 4 as your thresold</h3>

# %%
df2[df2['zscore'].abs() > 4]
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# 760              other  9 Bedroom       600.0   9.0   190.0    9
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft    zscore
# 9               36274  7.150766
# 45              33333  6.440528
# 190             27083  4.931181
# 733             23719  4.118790
# 760             31666  6.037955
# ...               ...       ...
# 13081           35000  6.843101
# 13094           27083  4.931181
# 13127           27083  4.931181
# 13185           44000  9.016560
# 13186           27083  4.931181
#
# [125 rows x 8 columns]

# %%
df4 = df2[df2['zscore'].abs() <= 4]
df4.shape
# Out:
# (13047, 8)

# %%
df2.shape[0] - df4.shape[0]
# Out:
# 125

# %%
df4.shape
# Out:
# (13047, 8)

# %%
df4.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft    zscore
# 0            3699 -0.715951
# 1            4615 -0.494741
# 2            4305 -0.569604
# 3            6245 -0.101103
# 4            4250 -0.582887

# %% [markdown]
# In this step also we removed 125 outliers. The result would be exactly same as 4 standard deviation
